# %% [markdown]
# #### import pandas as pd

# %%
import pandas as pd

# %%
df = pd.read_csv("cricket_test_match_data.csv")

# %%
df
# Out:
#                       Player       Span   Mat  Inns  NO   Runs    HS    Ave  \
# 0           DG Bradman (AUS)  1928-1948    52    80  10   6996   334  99.94
# 1             HC Brook (ENG)  2022-2024   13*    20   1   1181   186  62.15
# 2             AC Voges (AUS)  2015-2016    20    31   7   1485  269*  61.87
# 3            RG Pollock (SA)  1963-1970    23    41   4   2256   274  60.97
# 4            GA Headley (WI)  1930-1954    22    40   4   2190  270*  60.83
# 5          H Sutcliffe (ENG)  1924-1935    54    84   9   4555   194  60.73
# 6            E Paynter (ENG)  1931-1939    20    31   5   1540   243  59.23
# 7        KF Barrington (ENG)  1955-1968    82   131  15   6806   256  58.67
# 8             ED Weekes (WI)  1948-1958    48    81   5   4455   207  58.61
# 9           WR Hammond (ENG)  1927-1947    85   140  16   7249  336*  58.45
# 10                            1930-1954    22    40   4   2190  270*  60.83
# ...

# %% [markdown]
# #### Rename multiple columns in a list

# %%
df = df.rename(columns = {'Mat':'Matches', 'NO':'Not_Outs', 'HS':'Highest_Inns_Scorce', 'BF':'Balls_Faced', 'SR':'Battling_Strike_Rate'})

# %%
df.head()
# Out:
#              Player       Span Matches  Inns  Not_Outs  Runs  \
# 0  DG Bradman (AUS)  1928-1948      52    80        10  6996
# 1    HC Brook (ENG)  2022-2024     13*    20         1  1181
# 2    AC Voges (AUS)  2015-2016      20    31         7  1485
# 3   RG Pollock (SA)  1963-1970      23    41         4  2256
# 4   GA Headley (WI)  1930-1954      22    40         4  2190
#
#   Highest_Inns_Scorce    Ave Balls_Faced  Battling_Strike_Rate  100  50  0  \
# 0                 334  99.94       9800+                 58.60   29  13  7
# 1                 186  62.15        1287                 91.76    4   7  1
# 2                269*  61.87        2667                 55.68    5   4  2
# 3                 274  60.97       1707+                 54.48    7  11  1
# 4                270*  60.83        416+                 56.00   10   5  2
#
#      4s  6s
# 0  626+   6
# 1   141  23
# 2   186   5
# 3  246+  11
# 4  104+   1

# %% [markdown]
# #### Check Null Values

# %%
df.isnull().any()
# Out:
# Player                  False
# Span                    False
# Matches                 False
# Inns                    False
# Not_Outs                False
# Runs                    False
# Highest_Inns_Scorce     False
# Ave                     False
# Balls_Faced              True
# Battling_Strike_Rate    False
# 100                     False
# 50                      False
# 0                       False
# 4s                      False
# 6s                      False
# dtype: bool

# %%
df[df['Balls_Faced'].isna() == True]
# Out:
#              Player       Span Matches  Inns  Not_Outs  Runs  \
# 8    ED Weekes (WI)  1948-1958      48    81         5  4455
# 16  CL Walcott (WI)  1948-1960      44    74         7  3798
#
#    Highest_Inns_Scorce    Ave Balls_Faced  Battling_Strike_Rate  100  50  0  \
# 8                  207  58.61         NaN                   0.0   15  19  6
# 16                 220  56.68         NaN                   0.0   15  14  1
#
#       4s  6s
# 8   258+   2
# 16  107+  11

# %%
df['Balls_Faced'] = df['Balls_Faced'].fillna(0)

# %%
df[df['Player'] == 'ED Weekes (WI)']
df[df['Player'] == 'CL Walcott (WI)']
# Out:
#              Player       Span Matches  Inns  Not_Outs  Runs  \
# 16  CL Walcott (WI)  1948-1960      44    74         7  3798
#
#    Highest_Inns_Scorce    Ave Balls_Faced  Battling_Strike_Rate  100  50  0  \
# 16                 220  56.68           0                   0.0   15  14  1
#
#       4s  6s
# 16  107+  11

# %% [markdown]
# #### Drop Duplicates

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15     True
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23     True
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# 57     True
# 58    False
# 59    False
# 60    False
# 61    False
# 62    False
# 63    False
# 64    False
# 65    False
# dtype: bool

# %%
df[df['Player'].duplicated() == True]
# Out:
#             Player       Span Matches  Inns  Not_Outs  Runs  \
# 15  GS Sobers (WI)  1954-1974      93   160        21  8032
# 23  JB Hobbs (ENG)  1908-1930      61   102         7  5410
# 57   V Kohli (IND)  2011-2024     113   191        11  8848
#
#    Highest_Inns_Scorce    Ave Balls_Faced  Battling_Strike_Rate  100  50   0  \
# 15                365*  57.78       4063+                 53.58   26  30  12
# 23                 211  56.94       5363+                 46.22   15  28   4
# 57                254*  49.15       15924                 55.56   29  30  14
#
#       4s   6s
# 15  593+  32+
# 23  276+    8
# 57   991   26

# %%
df[df['Player'].isin(['GS Sobers (WI)', 'JB Hobbs (ENG)', 'V Kohli (IND)'])]
# Out:
#             Player       Span Matches  Inns  Not_Outs  Runs  \
# 11  GS Sobers (WI)  1954-1974      93   160        21  8032
# 14  JB Hobbs (ENG)  1908-1930      61   102         7  5410
# 15  GS Sobers (WI)  1954-1974      93   160        21  8032
# 23  JB Hobbs (ENG)  1908-1930      61   102         7  5410
# 53   V Kohli (IND)  2011-2024     113   191        11  8848
# 57   V Kohli (IND)  2011-2024     113   191        11  8848
#
#    Highest_Inns_Scorce    Ave Balls_Faced  Battling_Strike_Rate  100  50   0  \
# 11                365*  57.78       4063+                 53.58   26  30  12
# 14                 211  56.94       5363+                 46.22   15  28   4
# 15                365*  57.78       4063+                 53.58   26  30  12
# 23                 211  56.94       5363+                 46.22   15  28   4
# 53                254*  49.15       15924                 55.56   29  30  14
# 57                254*  49.15       15924                 55.56   29  30  14
#
# ...

# %%
df = df.drop_duplicates()

# %%
df[df['Player'].isin(['GS Sobers (WI)', 'JB Hobbs (ENG)', 'V Kohli (IND)'])]
# Out:
#             Player       Span Matches  Inns  Not_Outs  Runs  \
# 11  GS Sobers (WI)  1954-1974      93   160        21  8032
# 14  JB Hobbs (ENG)  1908-1930      61   102         7  5410
# 53   V Kohli (IND)  2011-2024     113   191        11  8848
#
#    Highest_Inns_Scorce    Ave Balls_Faced  Battling_Strike_Rate  100  50   0  \
# 11                365*  57.78       4063+                 53.58   26  30  12
# 14                 211  56.94       5363+                 46.22   15  28   4
# 53                254*  49.15       15924                 55.56   29  30  14
#
#       4s   6s
# 11  593+  32+
# 14  276+    8
# 53   991   26

# %% [markdown]
# #### Split up the Span into Start and End Date

# %%
# df['Span']
df['Span'].str.split(pat = '-')
# Out:
# 0     [1928, 1948]
# 1     [2022, 2024]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
# 5     [1924, 1935]
# 6     [1931, 1939]
# 7     [1955, 1968]
# 8     [1948, 1958]
# 9     [1927, 1947]
# 10    [1930, 1954]
# 11    [1954, 1974]
# 12    [2000, 2015]
# 13    [2010, 2024]
# 14    [1908, 1930]
# 16    [1948, 1960]
# 17    [1937, 1955]
# 18    [1995, 2013]
# 19    [1921, 1929]
# 20    [2010, 2024]
# 21    [1968, 1973]
# 22    [1993, 1995]
# 24    [1970, 1984]
# 25    [1935, 1951]
# 26    [1989, 2013]
# 27    [1990, 2006]
# 28    [1976, 1993]
# 29    [1996, 2012]
# 30    [1998, 2010]
# 31    [2000, 2017]
# 32    [1995, 2012]
# 33    [1920, 1929]
# 34    [1992, 2002]
# 35    [2005, 2013]
# 36    [1994, 2015]
# 37    [1971, 1987]
# 38    [1985, 2004]
# 39    [1994, 2009]
# 40    [2004, 2018]
# 41    [1978, 1994]
# 42    [2019, 2024]
# 43    [1974, 1991]
# 44    [1937, 1957]
# 45    [1997, 2014]
# 46    [2012, 2024]
# 47    [1992, 2007]
# 48    [2018, 2024]
# ...

# %%
df['Span'].str.split(pat = '-').str[1]
# Out:
# 0     1948
# 1     2024
# 2     2016
# 3     1970
# 4     1954
# 5     1935
# 6     1939
# 7     1968
# 8     1958
# 9     1947
# 10    1954
# 11    1974
# 12    2015
# 13    2024
# 14    1930
# 16    1960
# 17    1955
# 18    2013
# 19    1929
# 20    2024
# 21    1973
# 22    1995
# 24    1984
# 25    1951
# 26    2013
# 27    2006
# 28    1993
# 29    2012
# 30    2010
# 31    2017
# 32    2012
# 33    1929
# 34    2002
# 35    2013
# 36    2015
# 37    1987
# 38    2004
# 39    2009
# 40    2018
# 41    1994
# 42    2024
# 43    1991
# 44    1957
# 45    2014
# 46    2024
# 47    2007
# 48    2024
# 49    1963
# 50    1928
# 51    2013
# 52    2021
# 53    2024
# 54    2015
# 55    1966
# 56    1949
# 58    1905
# 59    2013
# 60    1963
# 61    1981
# 62    2014
# 63    1934
# 64    1938
# 65    1934
# Name: Span, dtype: object

# %%
df['Rookie_Year'] = df['Span'].str.split(pat = '-').str[0]

# %%
df['Final_Year'] = df['Span'].str.split(pat = '-').str[1]

# %%
df
# Out:
#                       Player       Span Matches  Inns  Not_Outs   Runs  \
# 0           DG Bradman (AUS)  1928-1948      52    80        10   6996
# 1             HC Brook (ENG)  2022-2024     13*    20         1   1181
# 2             AC Voges (AUS)  2015-2016      20    31         7   1485
# 3            RG Pollock (SA)  1963-1970      23    41         4   2256
# 4            GA Headley (WI)  1930-1954      22    40         4   2190
# 5          H Sutcliffe (ENG)  1924-1935      54    84         9   4555
# 6            E Paynter (ENG)  1931-1939      20    31         5   1540
# 7        KF Barrington (ENG)  1955-1968      82   131        15   6806
# 8             ED Weekes (WI)  1948-1958      48    81         5   4455
# 9           WR Hammond (ENG)  1927-1947      85   140        16   7249
# 10                            1930-1954      22    40         4   2190
# 11            GS Sobers (WI)  1954-1974      93   160        21   8032
# ...

# %% [markdown]
# #### Drop Columns

# %%
df = df.drop(['Span'], axis = 1)

# %%
df.head()
# Out:
#              Player Matches  Inns  Not_Outs  Runs Highest_Inns_Scorce    Ave  \
# 0  DG Bradman (AUS)      52    80        10  6996                 334  99.94
# 1    HC Brook (ENG)     13*    20         1  1181                 186  62.15
# 2    AC Voges (AUS)      20    31         7  1485                269*  61.87
# 3   RG Pollock (SA)      23    41         4  2256                 274  60.97
# 4   GA Headley (WI)      22    40         4  2190                270*  60.83
#
#   Balls_Faced  Battling_Strike_Rate  100  50  0    4s  6s Rookie_Year  \
# 0       9800+                 58.60   29  13  7  626+   6        1928
# 1        1287                 91.76    4   7  1   141  23        2022
# 2        2667                 55.68    5   4  2   186   5        2015
# 3       1707+                 54.48    7  11  1  246+  11        1963
# 4        416+                 56.00   10   5  2  104+   1        1930
#
#   Final_Year
# 0       1948
# 1       2024
# 2       2016
# 3       1970
# ...

# %% [markdown]
# #### Question:  Split up the Country from the Player

# %%
df['Country'] = df['Player'].str.split(pat = '(').str[1].str.split(pat = ')').str[0]

# %%
df['Player'] = df['Player'].str.split(pat = '(').str[0]

# %%
df.head()
# Out:
#         Player Matches  Inns  Not_Outs  Runs Highest_Inns_Scorce    Ave  \
# 0  DG Bradman       52    80        10  6996                 334  99.94
# 1    HC Brook      13*    20         1  1181                 186  62.15
# 2    AC Voges       20    31         7  1485                269*  61.87
# 3  RG Pollock       23    41         4  2256                 274  60.97
# 4  GA Headley       22    40         4  2190                270*  60.83
#
#   Balls_Faced  Battling_Strike_Rate  100  50  0    4s  6s Rookie_Year  \
# 0       9800+                 58.60   29  13  7  626+   6        1928
# 1        1287                 91.76    4   7  1   141  23        2022
# 2        2667                 55.68    5   4  2   186   5        2015
# 3       1707+                 54.48    7  11  1  246+  11        1963
# 4        416+                 56.00   10   5  2  104+   1        1930
#
#   Final_Year Country
# 0       1948     AUS
# 1       2024     ENG
# 2       2016     AUS
# ...

# %% [markdown]
# #### Change DataTypes

# %%
df.dtypes
# Out:
# Player                   object
# Matches                  object
# Inns                      int64
# Not_Outs                  int64
# Runs                      int64
# Highest_Inns_Scorce      object
# Ave                     float64
# Balls_Faced              object
# Battling_Strike_Rate    float64
# 100                       int64
# 50                        int64
# 0                         int64
# 4s                       object
# 6s                       object
# Rookie_Year              object
# Final_Year               object
# Country                  object
# dtype: object

# %%
# Removing the '*' from the Highest_Inns_Scorce to make it an int32
df['Highest_Inns_Scorce'] = df['Highest_Inns_Scorce'].str.split(pat = '*').str[0]

# %%
df['Highest_Inns_Scorce']
# Out:
# 0     334
# 1     186
# 2     269
# 3     274
# 4     270
# 5     194
# 6     243
# 7     256
# 8     207
# 9     336
# 10    270
# 11    365
# 12    319
# 13    239
# 14    211
# 16    220
# 17    364
# 18    224
# 19    122
# 20    251
# 21    183
# 22    227
# 24    247
# 25    231
# 26    248
# 27    400
# 28    280
# 29    270
# 30    223
# 31    313
# 32    257
# 33    201
# 34    232
# 35    195
# 36    203
# 37    236
# 38    200
# 39    380
# 40    278
# 41    205
# 42    190
# 43    291
# 44    278
# 45    374
# 46    254
# 47    329
# 48    215
# 49    261
# 50    182
# 51    319
# 52    215
# 53    254
# 54    329
# 55    144
# 56    189
# 58    144
# 59    231
# 60    205
# 61    250
# 62    277
# 63    266
# 64    232
# 65    127
# Name: Highest_Inns_Scorce, dtype: object

# %%
df['Highest_Inns_Scorce'] = df['Highest_Inns_Scorce'].astype('int')

# %%
df.dtypes
# Out:
# Player                   object
# Matches                  object
# Inns                      int64
# Not_Outs                  int64
# Runs                      int64
# Highest_Inns_Scorce       int32
# Ave                     float64
# Balls_Faced              object
# Battling_Strike_Rate    float64
# 100                       int64
# 50                        int64
# 0                         int64
# 4s                       object
# 6s                       object
# Rookie_Year              object
# Final_Year               object
# Country                  object
# dtype: object

# %% [markdown]
# #### Question: Fix Rookie Year & Final Year

# %%
# df['Rookie_Year'] = df['Rookie_Year'].astype('int')
# df['Final_Year'] = df['Final_Year'].astype('int')

df = df.astype({
    'Rookie_Year': 'int',
    'Final_Year': 'int'
})

# %%
df.dtypes
# Out:
# Player                   object
# Matches                  object
# Inns                      int64
# Not_Outs                  int64
# Runs                      int64
# Highest_Inns_Scorce       int32
# Ave                     float64
# Balls_Faced              object
# Battling_Strike_Rate    float64
# 100                       int64
# 50                        int64
# 0                         int64
# 4s                       object
# 6s                       object
# Rookie_Year               int32
# Final_Year                int32
# Country                  object
# dtype: object

# %%
df.head()
# Out:
#         Player Matches  Inns  Not_Outs  Runs  Highest_Inns_Scorce    Ave  \
# 0  DG Bradman       52    80        10  6996                  334  99.94
# 1    HC Brook      13*    20         1  1181                  186  62.15
# 2    AC Voges       20    31         7  1485                  269  61.87
# 3  RG Pollock       23    41         4  2256                  274  60.97
# 4  GA Headley       22    40         4  2190                  270  60.83
#
#   Balls_Faced  Battling_Strike_Rate  100  50  0    4s  6s  Rookie_Year  \
# 0       9800+                 58.60   29  13  7  626+   6         1928
# 1        1287                 91.76    4   7  1   141  23         2022
# 2        2667                 55.68    5   4  2   186   5         2015
# 3       1707+                 54.48    7  11  1  246+  11         1963
# 4        416+                 56.00   10   5  2  104+   1         1930
#
#    Final_Year Country
# 0        1948     AUS
# 1        2024     ENG
# 2        2016     AUS
# ...

# %%
df['Matches'] = df['Matches'].str.split(pat = '*').str[0].astype('int')

# %%
df.dtypes
# Out:
# Player                   object
# Matches                   int32
# Inns                      int64
# Not_Outs                  int64
# Runs                      int64
# Highest_Inns_Scorce       int32
# Ave                     float64
# Balls_Faced              object
# Battling_Strike_Rate    float64
# 100                       int64
# 50                        int64
# 0                         int64
# 4s                       object
# 6s                       object
# Rookie_Year               int32
# Final_Year                int32
# Country                  object
# dtype: object

# %%
df['4s'] = df['4s'].str.split(pat='+').str[0].astype('int')
df['6s'] = df['6s'].str.split(pat='+').str[0].astype('int')

# %%
df.dtypes
# Out:
# Player                   object
# Matches                   int32
# Inns                      int64
# Not_Outs                  int64
# Runs                      int64
# Highest_Inns_Scorce       int32
# Ave                     float64
# Balls_Faced              object
# Battling_Strike_Rate    float64
# 100                       int64
# 50                        int64
# 0                         int64
# 4s                        int32
# 6s                        int32
# Rookie_Year               int32
# Final_Year                int32
# Country                  object
# dtype: object

# %%
df['Balls_Faced'] = df['Balls_Faced'].str.split(pat='+').str[0]

# %%
df.isnull().any()
# Out:
# Player                  False
# Matches                 False
# Inns                    False
# Not_Outs                False
# Runs                    False
# Highest_Inns_Scorce     False
# Ave                     False
# Balls_Faced              True
# Battling_Strike_Rate    False
# 100                     False
# 50                      False
# 0                       False
# 4s                      False
# 6s                      False
# Rookie_Year             False
# Final_Year              False
# Country                  True
# dtype: bool

# %%
df[df['Balls_Faced'].isna() == True]
# Out:
#          Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_Scorce    Ave  \
# 8    ED Weekes        48    81         5  4455                  207  58.61
# 16  CL Walcott        44    74         7  3798                  220  56.68
#
#    Balls_Faced  Battling_Strike_Rate  100  50  0   4s  6s  Rookie_Year  \
# 8          NaN                   0.0   15  19  6  258   2         1948
# 16         NaN                   0.0   15  14  1  107  11         1948
#
#     Final_Year Country
# 8         1958      WI
# 16        1960      WI

# %%
df['Balls_Faced'] = df['Balls_Faced'].fillna(0)

# %%
df[df['Balls_Faced'].isna() == True]
# Out:
# Empty DataFrame
# Columns: [Player, Matches, Inns, Not_Outs, Runs, Highest_Inns_Scorce, Ave, Balls_Faced, Battling_Strike_Rate, 100, 50, 0, 4s, 6s, Rookie_Year, Final_Year, Country]
# Index: []

# %%
df['Balls_Faced'] = df['Balls_Faced'].str.split(pat='-').str[0].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [148], in <cell line: 1>()
# ----> 1 df['Balls_Faced'] = df['Balls_Faced'].str.split(pat='-').str[0].astype('int')
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
df.dtypes
# Out:
# Player                   object
# Matches                   int32
# Inns                      int64
# Not_Outs                  int64
# Runs                      int64
# Highest_Inns_Scorce       int32
# Ave                     float64
# Balls_Faced              object
# Battling_Strike_Rate    float64
# 100                       int64
# 50                        int64
# 0                         int64
# 4s                        int32
# 6s                        int32
# Rookie_Year               int32
# Final_Year                int32
# Country                  object
# dtype: object

# %% [markdown]
# #### Remove "Hon.FS Jackson" Row

# %%
df = df.drop(58, axis = 0)

# %%
df.isnull().any()
# Out:
# Player                  False
# Matches                 False
# Inns                    False
# Not_Outs                False
# Runs                    False
# Highest_Inns_Scorce     False
# Ave                     False
# Balls_Faced             False
# Battling_Strike_Rate    False
# 100                     False
# 50                      False
# 0                       False
# 4s                      False
# 6s                      False
# Rookie_Year             False
# Final_Year              False
# Country                  True
# dtype: bool

# %%
df
# Out:
#                Player  Matches  Inns  Not_Outs   Runs  Highest_Inns_Scorce  \
# 0         DG Bradman        52    80        10   6996                  334
# 1           HC Brook        13    20         1   1181                  186
# 2           AC Voges        20    31         7   1485                  269
# 3         RG Pollock        23    41         4   2256                  274
# 4         GA Headley        22    40         4   2190                  270
# 5        H Sutcliffe        54    84         9   4555                  194
# 6          E Paynter        20    31         5   1540                  243
# 7      KF Barrington        82   131        15   6806                  256
# 8          ED Weekes        48    81         5   4455                  207
# 9         WR Hammond        85   140        16   7249                  336
# 11         GS Sobers        93   160        21   8032                  365
# ...

# %%
df.dtypes
# Out:
# Player                   object
# Matches                   int32
# Inns                      int64
# Not_Outs                  int64
# Runs                      int64
# Highest_Inns_Scorce       int32
# Ave                     float64
# Balls_Faced              object
# Battling_Strike_Rate    float64
# 100                       int64
# 50                        int64
# 0                         int64
# 4s                        int32
# 6s                        int32
# Rookie_Year               int32
# Final_Year                int32
# Country                  object
# dtype: object

# %%
df['Balls_Faced'] = df['Balls_Faced'].astype('int')
# df['Battling_Strike_Rate'] = df['Battling_Strike_Rate'].astype('float')

# %%
df.dtypes
# Out:
# Player                   object
# Matches                   int32
# Inns                      int64
# Not_Outs                  int64
# Runs                      int64
# Highest_Inns_Scorce       int32
# Ave                     float64
# Balls_Faced               int32
# Battling_Strike_Rate    float64
# 100                       int64
# 50                        int64
# 0                         int64
# 4s                        int32
# 6s                        int32
# Rookie_Year               int32
# Final_Year                int32
# Country                  object
# dtype: object

# %% [markdown]
# #### **Question**: Build out Career_Length Column
# ##### _hint: convert rookie/final year and subtract_

# %%
df.head()
# Out:
#         Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_Scorce    Ave  \
# 0  DG Bradman        52    80        10  6996                  334  99.94
# 1    HC Brook        13    20         1  1181                  186  62.15
# 2    AC Voges        20    31         7  1485                  269  61.87
# 3  RG Pollock        23    41         4  2256                  274  60.97
# 4  GA Headley        22    40         4  2190                  270  60.83
#
#    Balls_Faced  Battling_Strike_Rate  100  50  0   4s  6s  Rookie_Year  \
# 0         9800                 58.60   29  13  7  626   6         1928
# 1         1287                 91.76    4   7  1  141  23         2022
# 2         2667                 55.68    5   4  2  186   5         2015
# 3         1707                 54.48    7  11  1  246  11         1963
# 4          416                 56.00   10   5  2  104   1         1930
#
#    Final_Year Country
# 0        1948     AUS
# 1        2024     ENG
# 2        2016     AUS
# ...

# %%
df['Career_Length'] = df['Final_Year'] - df['Rookie_Year']

# %%
df
# Out:
#                Player  Matches  Inns  Not_Outs   Runs  Highest_Inns_Scorce  \
# 0         DG Bradman        52    80        10   6996                  334
# 1           HC Brook        13    20         1   1181                  186
# 2           AC Voges        20    31         7   1485                  269
# 3         RG Pollock        23    41         4   2256                  274
# 4         GA Headley        22    40         4   2190                  270
# 5        H Sutcliffe        54    84         9   4555                  194
# 6          E Paynter        20    31         5   1540                  243
# 7      KF Barrington        82   131        15   6806                  256
# 8          ED Weekes        48    81         5   4455                  207
# 9         WR Hammond        85   140        16   7249                  336
# 11         GS Sobers        93   160        21   8032                  365
# ...

# %% [markdown]
# ### **Calculations with dataframe**

# %% [markdown]
# #### **Question 1**: Cricketers in this DF _(what is the Average Career Length)_

# %%
df['Career_Length'].mean()
# Out:
# 13.229508196721312

# %% [markdown]
# #### __Question 2__:   AVG Batting_Strike_Rate for cricketers who played over 10 years

# %%
df = df.rename(columns = {'Battling_Strike_Rate':'Batting_Strike_Rate',})

# %%
df[df['Career_Length'] > 10]['Batting_Strike_Rate'].mean()
# Out:
# 49.061860465116276

# %% [markdown]
# #### __Question 3__:   find number of cricketers who played before 1960

# %%
df[df['Rookie_Year'] < 1960]['Player'].count()
# Out:
# 22

# %% [markdown]
# #### __Question 4__: Max Highest Inns Score by country

# %%
df.groupby('Country')['Highest_Inns_Scorce'].max().to_frame('High_Inns_Country').reset_index().sort_values('High_Inns_Country', ascending = False)
# Out:
#     Country  High_Inns_Country
# 5    ICC/WI                400
# 0       AUS                380
# 10       SL                374
# 11       WI                365
# 1       ENG                364
# 3   ICC/PAK                329
# 2   ICC/IND                319
# 8       PAK                313
# 9        SA                278
# 4    ICC/SA                277
# 6       IND                254
# 7        NZ                251
# 12      ZIM                232

# %% [markdown]
# #### __Question 5__: Hundreds, Fifties, ducks (0) AVG by Country

# %%
df.groupby('Country')[['100', '50', '0']].mean()
# Out:
#                100         50          0
# Country
# AUS      20.625000  28.375000   8.562500
# ENG      13.000000  22.083333   4.416667
# ICC/IND  29.500000  47.500000  12.000000
# ICC/PAK  25.000000  46.000000  15.000000
# ICC/SA   36.000000  48.000000  13.500000
# ICC/WI   34.000000  48.000000  17.000000
# IND      29.500000  36.500000  10.750000
# NZ       18.500000  22.000000   6.000000
# PAK      21.250000  28.000000   9.500000
# SA        9.800000  20.200000   3.400000
# SL       28.666667  44.000000  12.333333
# WI       16.625000  25.625000   7.250000
# ZIM      12.000000  27.000000   5.000000
